# %%
# import TensorFlow
import tensorflow as tf

#Check the version of TensorFlow you are using
print(tf.__version__)
print(tf.config.list_physical_devices('CPU'))
# Out:
# 2.15.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import numpy as np
import pandas as pd

# %%
series = pd.read_excel('/content/sample_data/wind_mill_dataset.xlsx',index_col="DateTime")
series.head()
# Out:
#                      Air temperature (°C)  Pressure (atm)  Wind speed (m/s)  \
# DateTime
# 01-01-2022 06:25:08                    46        1.566323          7.821116
# 01-01-2022 19:07:48                    47        0.244996          2.451113
# 01-01-2022 14:35:28                    26        1.269813         13.170429
# 01-01-2022 10:47:12                    22        0.247692          1.427477
# 01-01-2022 07:29:58                    23        0.141071          2.763579
#
#                      Wind direction (deg)  Power generated by system (kW)
# DateTime
# 01-01-2022 06:25:08                   110                     1575.282483
# 01-01-2022 19:07:48                   209                     2709.400866
# 01-01-2022 14:35:28                     0                      456.224207
# 01-01-2022 10:47:12                    57                     3394.727121
# 01-01-2022 07:29:58                    92                     3625.480094

# %%
# Cleaning Data
series['Power_generated_by_system (kW)'].replace(0, np.nan, inplace=True)
series['Power_generated_by_system (kW)'].fillna(method='ffill', inplace=True)
print(series)
# Out:
#                      Air temperature (°C)  Pressure (atm)  Wind speed (m/s)  \
# DateTime
# 01-01-2022 06:25:08                    46        1.566323          7.821116
# 01-01-2022 19:07:48                    47        0.244996          2.451113
# 01-01-2022 14:35:28                    26        1.269813         13.170429
# 01-01-2022 10:47:12                    22        0.247692          1.427477
# 01-01-2022 07:29:58                    23        0.141071          2.763579
# ...                                   ...             ...               ...
# 25-03-2022 07:22:45                    37        0.796958          3.516333
# 25-03-2022 20:05:42                    13        0.633826         17.915798
# 25-03-2022 14:03:06                    22        0.934775         10.932041
# 25-03-2022 00:17:15                    24        0.571159         10.088716
# 25-03-2022 02:59:44                    14        1.923223          3.424166
#
#                      Wind direction (deg)  Power generated by system (kW)
# DateTime
# 01-01-2022 06:25:08                   110                     1575.282483
# 01-01-2022 19:07:48                   209                     2709.400866
# 01-01-2022 14:35:28                     0                      456.224207
# 01-01-2022 10:47:12                    57                     3394.727121
# 01-01-2022 07:29:58                    92                     3625.480094
# ...                                   ...                             ...
# 25-03-2022 07:22:45                    76                     4957.988878
# 25-03-2022 20:05:42                    61                     4916.079933
# 25-03-2022 14:03:06                   156                     3175.122831
# 25-03-2022 00:17:15                   293                     2214.352531
# 25-03-2022 02:59:44                   124                     2455.704846
#
# [2000 rows x 5 columns]

# %%
# initialize variables
batch_size_exp = 1
epoch_exp = 7
neurons_exp = 10
predict_values_exp = 168
lag_exp=24

# %%
# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# %%
# scale train and test data to [-1, 1]
from sklearn.preprocessing import MinMaxScaler
def scale(train, test):
    # fit scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train)
    # transform train
    train = train.reshape(train.shape[0], train.shape[1])
    train_scaled = scaler.transform(train)
    # transform test
    test = test.reshape(test.shape[0], test.shape[1])
    test_scaled = scaler.transform(test)
    return scaler, train_scaled, test_scaled

# %%
# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
    new_row = [x for x in X] + [value]
    array = np.array(new_row)
    array = array.reshape(1, len(array))
    inverted = scaler.inverse_transform(array)
    return inverted[0, -1]

# %%
# fit an LSTM network to training data
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
def fit_lstm(train, batch_size, nb_epoch, neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epoch):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=1, shuffle=False)
        model.reset_states()
    return model

# %%
# make a one-step forecast
def forecast_lstm(model, batch_size, X):
    X = X.reshape(1, 1, len(X))
    #print(X)
    yhat = model.predict(X, batch_size=1)
    return yhat[0,0]

# %%
print(series.columns)
# Out:
# Index(['Air temperature (°C)', 'Pressure (atm)', 'Wind speed (m/s)',
#        'Wind direction (deg)', 'Power generated by system (kW)'],
#       dtype='object')

# %%
# Drop all the features as we will not be having any in production
del series['Air_temperature (c)']
del series['Pressure (atm)']
del series['Wind_speed (m/s)']
del series['Wind_direction (deg)']

# %%
for i in range(0,10):
  series = series[:-1]
series.tail()
# Out:
#                      Power generated by system (kW)
# DateTime
# 24-03-2022 05:52:07                      652.267436
# 24-03-2022 06:29:28                     3813.430852
# 24-03-2022 09:41:39                      341.758574
# 24-03-2022 18:36:25                       62.963063
# 24-03-2022 18:57:29                     4491.117594

# %%
# create a differenced series
from pandas import Series
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return Series(diff)

# %%
# transform data to be stationary
raw_values = series.values
diff_values = difference(raw_values, 1)

# %%
# Print the raw and differenced values
print("Raw values:", raw_values)
print("Differenced values:", diff_values)
# Out:
# Raw values: [[1575.28248304]
#  [2709.40086638]
#  [ 456.22420652]
#  ...
#  [ 341.75857425]
#  [  62.96306334]
#  [4491.11759416]]
# Differenced values: 0        [1134.1183833431032]
# 1       [-2253.1766598598233]
# 2         [2938.502914882073]
# 3        [230.75297308490417]
# 4        [1199.6780200613398]
#                 ...
# 1984    [-3310.2409734205257]
# 1985      [3161.163416386238]
# 1986    [-3471.6722780202113]
# 1987     [-278.7955109153572]
# 1988      [4428.154530823337]
# Length: 1989, dtype: object

# %%
# frame a sequence as a supervised learning problem
from pandas import DataFrame
from pandas import concat
def timeseries_to_supervised(data, lag=1):
    df = DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df

# %%
# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, lag_exp)
supervised_values = supervised.values

# %%
# Print the supervised values
print("Supervised values:", supervised_values)
# Out:
# Supervised values: [[0 0 0 ... 0 0
#   array([ 1.00000000e+00, -1.32132714e+00, -5.37000225e+00,  9.90000000e+01,
#           1.13411838e+03])                                                  ]
#  [array([ 1.00000000e+00, -1.32132714e+00, -5.37000225e+00,  9.90000000e+01,
#           1.13411838e+03])
#   0 0 ... 0 0
#   array([-2.10000000e+01,  1.02481759e+00,  1.07193157e+01, -2.09000000e+02,
#          -2.25317666e+03])                                                  ]
#  [array([-2.10000000e+01,  1.02481759e+00,  1.07193157e+01, -2.09000000e+02,
#          -2.25317666e+03])
#   array([ 1.00000000e+00, -1.32132714e+00, -5.37000225e+00,  9.90000000e+01,
#           1.13411838e+03])
#   0 ... 0 0
#   array([-4.00000000e+00, -1.02212126e+00, -1.17429522e+01,  5.70000000e+01,
#           2.93850291e+03])                                                  ]
#  ...
#  [array([ 1.20000000e+01, -3.74395465e-01,  8.74986262e+00, -1.05000000e+02,
#           3.16116342e+03])
#   array([ 9.00000000e+00,  4.24667753e-02, -1.37257072e+01,  1.97000000e+02,
#          -3.31024097e+03])
#   array([9.00000000e+00, 2.53769802e-01, 1.78701947e+01, 6.70000000e+01,
#          2.38506238e+03])
#   ...
#   array([ 3.00000000e+01, -2.41411209e-01,  1.62939369e+01, -2.34000000e+02,
#           3.06196223e+03])
#   array([-3.50000000e+01, -1.27831618e-02, -1.18066357e+01,  1.40000000e+01,
#           8.60715519e+02])
#   array([ 1.00000000e+00,  8.26608853e-01, -2.31029298e+00,  8.00000000e+00,
#          -3.47167228e+03])                                                  ]
#  [array([ 1.00000000e+00,  8.26608853e-01, -2.31029298e+00,  8.00000000e+00,
#          -3.47167228e+03])
#   array([ 1.20000000e+01, -3.74395465e-01,  8.74986262e+00, -1.05000000e+02,
#           3.16116342e+03])
#   array([ 9.00000000e+00,  4.24667753e-02, -1.37257072e+01,  1.97000000e+02,
#          -3.31024097e+03])
#   ...
#   array([-3.60000000e+01,  8.62825606e-03, -3.70524648e+00,  2.96000000e+02,
#          -1.70163020e+03])
#   array([ 3.00000000e+01, -2.41411209e-01,  1.62939369e+01, -2.34000000e+02,
#           3.06196223e+03])
#   array([  -8.        ,    0.29101365,   -2.36718439,   14.        ,
#          -278.79551092])                                            ]
#  [array([  -8.        ,    0.29101365,   -2.36718439,   14.        ,
#          -278.79551092])
#   array([ 1.00000000e+00,  8.26608853e-01, -2.31029298e+00,  8.00000000e+00,
#          -3.47167228e+03])
#   array([ 1.20000000e+01, -3.74395465e-01,  8.74986262e+00, -1.05000000e+02,
#           3.16116342e+03])
#   ...
#   array([ 1.40000000e+01,  2.42246015e-01,  9.38701946e+00,  3.70000000e+01,
#          -6.82859203e+02])
#   array([-3.60000000e+01,  8.62825606e-03, -3.70524648e+00,  2.96000000e+02,
#          -1.70163020e+03])
#   array([-3.30000000e+01,  1.27944457e-01,  6.01579081e-01, -2.04000000e+02,
#           4.42815453e+03])                                                  ]]

# %%
# split data into train and test-sets
train, test = supervised_values[0:-predict_values_exp], supervised_values[-predict_values_exp:]

# %%
# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)

# %%
# fit the model
lstm_model = fit_lstm(train_scaled, batch_size_exp, epoch_exp, neurons_exp)
# Out:
# 1821/1821 [==============================] - 10s 4ms/step - loss: 0.1446
# 1821/1821 [==============================] - 8s 4ms/step - loss: 0.1011
# 1821/1821 [==============================] - 6s 4ms/step - loss: 0.0967
# 1821/1821 [==============================] - 7s 4ms/step - loss: 0.0946
# 1821/1821 [==============================] - 7s 4ms/step - loss: 0.0929
# 1821/1821 [==============================] - 6s 4ms/step - loss: 0.0914
# 1821/1821 [==============================] - 7s 4ms/step - loss: 0.0899

# %%
import tensorflow as tf

tf.get_logger().setLevel('ERROR')

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
# walk-forward validation on the test data
predictions = list()
expectations = list()
test_pred = list()
 #Classify power level using CNN
def classify_power_level(prediction, low_threshold, high_threshold):
    if prediction < low_threshold:
        return 'low'
    elif prediction >= high_threshold:
        return 'high'
    else:
        return 'mid'



# Set your low and high thresholds
low_threshold = 1000
high_threshold = 2500

# Display Hour, Predicted, Expected, and Classified Power Level
expectations = np.array([])
for i in range(len(test_scaled)):
    X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
    yhat = forecast_lstm(lstm_model, 1, X)  # make one-step forecast
    test_pred = np.array([yhat] + list(test_pred))  # Convert to numpy array for concatenation
    if i + 1 < len(test_scaled):
        end_idx = min(len(test_scaled[i+1]), len(test_pred))
        test_scaled[i + 1] = np.concatenate((test_pred[:end_idx], test_scaled[i + 1, end_idx:]), axis=0)
    yhat = invert_scale(scaler, X, yhat)
    yhat = inverse_difference(raw_values, yhat, len(test_scaled) + 1 - i)
    predictions = np.append(predictions, yhat)  # Use np.append instead
    expected = raw_values[len(train) + i + 1]
    expectations = np.append(expectations, expected)  # Add expected value to the array
    classified_power_level = classify_power_level(yhat, low_threshold, high_threshold)
    #print('Hour=%d, Predicted=%f, Expected=%f, Classified=%s' % (i + 1, yhat, expected, classified_power_level))

# %%
for i in range(len(predictions)):
    predicted_power = predictions[i]
    expected_power = expectations[i]
    classified_power_level = classify_power_level(predicted_power, low_threshold, high_threshold)
    print('Hour=%d, Predicted=%f, Expected=%f, Classified=%s' % (i + 1, predicted_power, expected_power, classified_power_level))
# Out:
# Hour=1, Predicted=4105.351739, Expected=1034.205191, Classified=high
# Hour=2, Predicted=601.244969, Expected=3117.539050, Classified=low
# Hour=3, Predicted=2494.367819, Expected=1788.583825, Classified=mid
# Hour=4, Predicted=1629.455994, Expected=4222.028061, Classified=mid
# Hour=5, Predicted=4788.757845, Expected=2266.498693, Classified=high
# Hour=6, Predicted=1881.613446, Expected=3632.206791, Classified=mid
# Hour=7, Predicted=3448.848193, Expected=477.681038, Classified=high
# Hour=8, Predicted=851.965709, Expected=1980.121732, Classified=low
# Hour=9, Predicted=1708.170729, Expected=4916.207182, Classified=mid
# Hour=10, Predicted=5172.325661, Expected=4042.301447, Classified=high
# Hour=11, Predicted=3578.241364, Expected=799.704012, Classified=high
# Hour=12, Predicted=1166.417234, Expected=1388.820247, Classified=mid
# Hour=13, Predicted=1650.609749, Expected=1649.079044, Classified=mid
# Hour=14, Predicted=1338.742035, Expected=3251.827802, Classified=mid
# Hour=15, Predicted=3343.513034, Expected=3784.973797, Classified=high
# Hour=16, Predicted=3837.743136, Expected=3747.633044, Classified=high
# Hour=17, Predicted=3912.776515, Expected=2549.370282, Classified=high
# Hour=18, Predicted=2546.748976, Expected=4054.102689, Classified=high
# Hour=19, Predicted=3994.263778, Expected=2185.390414, Classified=high
# Hour=20, Predicted=2298.240542, Expected=619.402826, Classified=mid
# Hour=21, Predicted=456.317050, Expected=2822.209208, Classified=low
# Hour=22, Predicted=3074.362095, Expected=4761.506923, Classified=high
# Hour=23, Predicted=4560.370423, Expected=3964.968257, Classified=high
# Hour=24, Predicted=4003.403018, Expected=2893.503238, Classified=high
# Hour=25, Predicted=2941.371407, Expected=3234.028302, Classified=high
# Hour=26, Predicted=3307.946146, Expected=4652.810135, Classified=high
# Hour=27, Predicted=4606.387724, Expected=2141.713972, Classified=high
# Hour=28, Predicted=2153.369153, Expected=1656.970695, Classified=mid
# Hour=29, Predicted=1723.343814, Expected=4886.207825, Classified=mid
# Hour=30, Predicted=4866.234262, Expected=4317.215668, Classified=high
# Hour=31, Predicted=4382.272457, Expected=1615.217923, Classified=high
# Hour=32, Predicted=1553.249203, Expected=2318.902987, Classified=mid
# Hour=33, Predicted=2424.305651, Expected=2075.390645, Classified=mid
# Hour=34, Predicted=2070.869835, Expected=745.478393, Classified=mid
# Hour=35, Predicted=736.580624, Expected=4789.096619, Classified=low
# Hour=36, Predicted=4842.172802, Expected=2021.562156, Classified=high
# Hour=37, Predicted=2007.923158, Expected=4376.645413, Classified=mid
# Hour=38, Predicted=4422.544554, Expected=946.781138, Classified=high
# Hour=39, Predicted=956.098815, Expected=2739.354053, Classified=low
# Hour=40, Predicted=2755.906500, Expected=119.806926, Classified=high
# Hour=41, Predicted=128.302443, Expected=3821.102419, Classified=low
# Hour=42, Predicted=3842.305239, Expected=2904.569491, Classified=high
# Hour=43, Predicted=2939.341873, Expected=3127.947917, Classified=high
# Hour=44, Predicted=3122.838144, Expected=258.604413, Classified=high
# Hour=45, Predicted=290.624338, Expected=1055.191651, Classified=low
# Hour=46, Predicted=1070.016788, Expected=371.654362, Classified=mid
# Hour=47, Predicted=403.957199, Expected=1444.571579, Classified=low
# Hour=48, Predicted=1446.234315, Expected=3137.195038, Classified=mid
# Hour=49, Predicted=3162.634493, Expected=2830.929922, Classified=high
# Hour=50, Predicted=2852.938113, Expected=3060.749108, Classified=high
# Hour=51, Predicted=3073.515648, Expected=2746.256357, Classified=high
# Hour=52, Predicted=2770.873378, Expected=1365.143978, Classified=high
# Hour=53, Predicted=1373.909014, Expected=1222.537487, Classified=mid
# Hour=54, Predicted=1252.913576, Expected=685.298418, Classified=mid
# Hour=55, Predicted=694.376822, Expected=4245.354375, Classified=low
# Hour=56, Predicted=4267.624603, Expected=3082.396793, Classified=high
# Hour=57, Predicted=3101.653203, Expected=932.555063, Classified=high
# Hour=58, Predicted=946.208933, Expected=886.046899, Classified=low
# Hour=59, Predicted=909.751672, Expected=4365.178008, Classified=low
# Hour=60, Predicted=4381.024779, Expected=3713.654319, Classified=high
# Hour=61, Predicted=3732.931513, Expected=3296.995400, Classified=high
# Hour=62, Predicted=3312.749381, Expected=2034.320538, Classified=high
# Hour=63, Predicted=2056.278895, Expected=1309.877821, Classified=mid
# Hour=64, Predicted=1327.357452, Expected=4897.253816, Classified=mid
# Hour=65, Predicted=4914.426693, Expected=3986.197875, Classified=high
# Hour=66, Predicted=4006.014499, Expected=1508.896116, Classified=high
# Hour=67, Predicted=1526.466675, Expected=4237.823981, Classified=mid
# Hour=68, Predicted=4258.252141, Expected=3794.659743, Classified=high
# Hour=69, Predicted=3809.830254, Expected=1485.402749, Classified=high
# Hour=70, Predicted=1506.534878, Expected=2132.764271, Classified=mid
# Hour=71, Predicted=2150.111998, Expected=929.767227, Classified=mid
# Hour=72, Predicted=948.058607, Expected=555.262222, Classified=low
# Hour=73, Predicted=574.444592, Expected=3613.810164, Classified=low
# Hour=74, Predicted=3631.190354, Expected=1337.559287, Classified=high
# Hour=75, Predicted=1357.254235, Expected=4100.296829, Classified=mid
# Hour=76, Predicted=4117.381077, Expected=4978.043558, Classified=high
# Hour=77, Predicted=4997.826450, Expected=383.099070, Classified=high
# Hour=78, Predicted=400.677192, Expected=2365.175625, Classified=low
# Hour=79, Predicted=2383.681462, Expected=4010.312797, Classified=mid
# Hour=80, Predicted=4029.231971, Expected=3944.754483, Classified=high
# Hour=81, Predicted=3962.881122, Expected=3799.985792, Classified=high
# Hour=82, Predicted=3818.565677, Expected=1744.974677, Classified=high
# Hour=83, Predicted=1763.035451, Expected=2269.266278, Classified=mid
# Hour=84, Predicted=2288.467152, Expected=2974.841787, Classified=mid
# Hour=85, Predicted=2992.672385, Expected=4869.702918, Classified=high
# Hour=86, Predicted=4888.401851, Expected=1637.736355, Classified=high
# Hour=87, Predicted=1656.151244, Expected=4615.719439, Classified=mid
# Hour=88, Predicted=4634.159200, Expected=1346.784591, Classified=high
# Hour=89, Predicted=1365.377067, Expected=4945.372327, Classified=mid
# Hour=90, Predicted=4963.451696, Expected=3351.318434, Classified=high
# Hour=91, Predicted=3370.262744, Expected=2317.557402, Classified=high
# Hour=92, Predicted=2335.597566, Expected=3066.952140, Classified=mid
# Hour=93, Predicted=3085.616896, Expected=1362.655845, Classified=high
# Hour=94, Predicted=1381.085379, Expected=1370.869288, Classified=mid
# Hour=95, Predicted=1389.246861, Expected=567.772719, Classified=mid
# Hour=96, Predicted=586.310553, Expected=570.251489, Classified=low
# Hour=97, Predicted=588.590313, Expected=1738.358707, Classified=low
# Hour=98, Predicted=1756.996848, Expected=3814.277389, Classified=mid
# Hour=99, Predicted=3832.508397, Expected=3039.855838, Classified=high
# Hour=100, Predicted=3058.449765, Expected=512.922802, Classified=high
# Hour=101, Predicted=531.334480, Expected=4261.182625, Classified=low
# Hour=102, Predicted=4279.641665, Expected=3006.838135, Classified=high
# Hour=103, Predicted=3025.267084, Expected=4804.277884, Classified=high
# Hour=104, Predicted=4822.714871, Expected=3350.927337, Classified=high
# Hour=105, Predicted=3369.467415, Expected=875.874319, Classified=high
# Hour=106, Predicted=894.197468, Expected=2368.916812, Classified=low
# Hour=107, Predicted=2387.468276, Expected=3242.487988, Classified=mid
# Hour=108, Predicted=3260.880889, Expected=141.323505, Classified=high
# Hour=109, Predicted=159.803722, Expected=74.551321, Classified=low
# Hour=110, Predicted=92.989832, Expected=647.015003, Classified=low
# Hour=111, Predicted=665.451115, Expected=1258.322175, Classified=low
# Hour=112, Predicted=1276.820293, Expected=2147.745618, Classified=mid
# Hour=113, Predicted=2166.127798, Expected=2437.202369, Classified=mid
# Hour=114, Predicted=2455.714592, Expected=690.138045, Classified=mid
# Hour=115, Predicted=708.554467, Expected=3366.957896, Classified=low
# Hour=116, Predicted=3385.419271, Expected=2980.690308, Classified=high
# Hour=117, Predicted=2999.135653, Expected=1472.320494, Classified=high
# Hour=118, Predicted=1490.775310, Expected=68.299417, Classified=mid
# Hour=119, Predicted=86.759707, Expected=388.239577, Classified=low
# Hour=120, Predicted=406.662130, Expected=1958.473878, Classified=low
# Hour=121, Predicted=1976.956877, Expected=769.871756, Classified=mid
# Hour=122, Predicted=788.300185, Expected=1884.098031, Classified=low
# Hour=123, Predicted=1902.562244, Expected=3140.913023, Classified=mid
# Hour=124, Predicted=3159.351470, Expected=2736.187139, Classified=high
# Hour=125, Predicted=2754.647119, Expected=1155.879416, Classified=high
# Hour=126, Predicted=1174.331613, Expected=1719.112456, Classified=mid
# Hour=127, Predicted=1737.549526, Expected=3070.155992, Classified=mid
# Hour=128, Predicted=3088.625260, Expected=4304.275140, Classified=high
# Hour=129, Predicted=4322.710285, Expected=3766.067194, Classified=high
# Hour=130, Predicted=3784.528150, Expected=2767.000134, Classified=high
# Hour=131, Predicted=2785.444038, Expected=1811.464992, Classified=high
# Hour=132, Predicted=1829.920318, Expected=1825.256388, Classified=mid
# Hour=133, Predicted=1843.706441, Expected=4397.086551, Classified=mid
# Hour=134, Predicted=4415.532143, Expected=196.217880, Classified=high
# Hour=135, Predicted=214.677550, Expected=4939.913222, Classified=low
# Hour=136, Predicted=4958.355711, Expected=3321.877054, Classified=high
# Hour=137, Predicted=3340.332819, Expected=3405.688495, Classified=high
# Hour=138, Predicted=3424.135592, Expected=189.989187, Classified=high
# Hour=139, Predicted=208.443674, Expected=3027.646374, Classified=low
# Hour=140, Predicted=3046.094429, Expected=2423.890300, Classified=high
# Hour=141, Predicted=2442.340244, Expected=528.894534, Classified=mid
# Hour=142, Predicted=547.348921, Expected=1389.610054, Classified=low
# Hour=143, Predicted=1408.056421, Expected=4451.572281, Classified=mid
# Hour=144, Predicted=4470.026467, Expected=2749.942079, Classified=high
# Hour=145, Predicted=2768.389742, Expected=2067.082876, Classified=high
# Hour=146, Predicted=2085.536387, Expected=363.410779, Classified=mid
# Hour=147, Predicted=381.859445, Expected=3570.607637, Classified=low
# Hour=148, Predicted=3589.058493, Expected=3514.254117, Classified=high
# Hour=149, Predicted=3532.706442, Expected=3070.218035, Classified=high
# Hour=150, Predicted=3088.666290, Expected=2551.313231, Classified=high
# Hour=151, Predicted=2569.765976, Expected=2168.922011, Classified=high
# Hour=152, Predicted=2187.371142, Expected=2966.355465, Classified=mid
# Hour=153, Predicted=2984.807543, Expected=1166.977259, Classified=high
# Hour=154, Predicted=1185.426700, Expected=4706.295321, Classified=mid
# Hour=155, Predicted=4724.746542, Expected=2943.972646, Classified=high
# Hour=156, Predicted=2962.423775, Expected=1555.962222, Classified=high
# Hour=157, Predicted=1574.411901, Expected=2248.399254, Classified=mid
# Hour=158, Predicted=2266.850840, Expected=4028.423944, Classified=mid
# Hour=159, Predicted=4046.873879, Expected=808.080304, Classified=high
# Hour=160, Predicted=826.531816, Expected=1464.178112, Classified=low
# Hour=161, Predicted=1482.627882, Expected=3397.540114, Classified=mid
# Hour=162, Predicted=3415.991398, Expected=1577.446032, Classified=high
# Hour=163, Predicted=1595.896687, Expected=3962.508409, Classified=mid
# Hour=164, Predicted=3980.958709, Expected=652.267436, Classified=high
# Hour=165, Predicted=670.718620, Expected=3813.430852, Classified=low
# Hour=166, Predicted=3831.881024, Expected=341.758574, Classified=high
# Hour=167, Predicted=360.209749, Expected=62.963063, Classified=low
# Hour=168, Predicted=81.413217, Expected=4491.117594, Classified=low

# %%
# Convert predictions and expectations to numpy arrays
expectations = np.array(expectations)
predictions = np.array(predictions)

# Calculate MAPE
mape = np.mean(np.abs((expectations - predictions) / expectations)) * 100
print("Mean Absolute Percent Error: ", mape)
# Out:
# Mean Absolute Percent Error:  165.6225458383757

# %%
from matplotlib import pyplot
pyplot.figure(figsize=(20,8))
pyplot.plot(raw_values[-predict_values_exp:], label="True")
pyplot.plot(predictions, label="Predicted")
pyplot.legend(loc='upper right')
pyplot.xlabel("Number of hours")
pyplot.ylabel("Power generated by system (kW)")
pyplot.show()

# %%
from keras.models import save_model

# Save the model
lstm_model.save('lstm_model.h5')

# %%
import numpy as np
from tensorflow.keras.models import load_model

# Define the function to normalize input features
def normalize_features(features):
    # Assuming the original range for each feature was 0 to 100
    return features / 1000.0

# Define the function to denormalize the prediction
def denormalize_prediction(prediction):
    # Assuming the denormalization range for power is 0 to 6000 kW
    return abs(prediction) * 60000.0

# Load the trained LSTM model
lstm_model = load_model('/content/lstm_model.h5')

# Take user input for the four features
air_temperature = float(input("Enter air temperature (°C): "))
pressure = float(input("Enter pressure (atm): "))
wind_speed = float(input("Enter wind speed (m/s): "))
wind_direction = float(input("Enter wind direction (deg): "))

# Normalize the input features
input_features = np.array([[air_temperature, pressure, wind_speed, wind_direction]])
normalized_features = normalize_features(input_features)

# Expand the input features to match the expected shape (batch_size, 1, 24)
normalized_features_expanded = np.zeros((normalized_features.shape[0], 1, 24))
normalized_features_expanded[:, :, :4] = normalized_features

# Make a prediction using the LSTM model
prediction = lstm_model.predict(normalized_features_expanded)

# Denormalize the prediction
predicted_power = denormalize_prediction(prediction[0][0])

# Display the predicted power output
print("Predicted power generated by the system:", predicted_power, "kW")
# Out:
# Enter air temperature (°C): 46
# Enter pressure (atm): 1.56
# Enter wind speed (m/s): 7.8
# Enter wind direction (deg): 110
# 1/1 [==============================] - 1s 566ms/step
# Predicted power generated by the system: 2847.7574586868286 kW
